# %%
import numpy as np # linear algebra
import matplotlib.pyplot as plt # Plotting
import pandas as pd

# %%
#importing the data set
dataset = pd.read_csv('C:/Users/Factory/Desktop/Salary_Data.csv')
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:, 1].values
X = X.reshape(-1,1)
y = y.reshape(-1,1)

# %%
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in c:\users\factory\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\factory\anaconda3\lib\site-packages (from sklearn) (0.23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\factory\anaconda3\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\factory\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.19.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\factory\anaconda3\lib\site-packages (from scikit-learn->sklearn) (0.17.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\factory\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.5.2)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(X_test)

# %%
#Visualsing the training set results
plt.scatter(X_train,y_train,color='red')
plt.plot(X_train,regressor.predict(X_train),)
plt.title('Salary vs Experience(Train set)')
plt.xlabel('Experience in years')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
#Visualising the test set results
plt.scatter(X_test,y_test,color='red')
plt.plot(X_train,regressor.predict(X_train),color='blue')
plt.title('Salary vs experience(Test set)')
plt.xlabel('Experience in years')
plt.ylabel('Salary')
plt.show()
